# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r"C:\Users\kollu\Downloads\framingham.csv")
data.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
data.tail()
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 4233                0             1         0    313.0  179.0   92.0  25.97
# 4234                0             0         0    207.0  126.5   80.0  19.71
# 4235                0             0         0    248.0  131.0   72.0  22.00
# 4236                0             0         0    210.0  126.5   87.0  19.16
# 4237                0             0         0    269.0  133.5   83.0  21.47
#
#       heartRate  glucose  TenYearCHD
# 4233       66.0     86.0           1
# 4234       65.0     68.0           0
# ...

# %%
data.sample(10)
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 1863     0   50        2.0              1        20.0     0.0
# 1970     0   46        2.0              0         0.0     0.0
# 2342     0   41        4.0              1         9.0     0.0
# 21       0   43        1.0              0         0.0     0.0
# 2061     1   57        3.0              1        20.0     0.0
# 3221     0   36        1.0              1         5.0     0.0
# 3408     0   59        1.0              0         0.0     0.0
# 1998     0   51        NaN              1        15.0     0.0
# 730      0   40        3.0              0         0.0     0.0
# 330      0   43        1.0              1         1.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 1863                0             0         0    235.0  121.0   78.0  23.01
# 1970                0             0         0    212.0  132.0   82.0  34.52
# ...

# %%
data.shape
# Out:
# (4238, 16)

# %%
data.columns 
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
#missing values
data.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
#Duplicate values
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
sns.set(style="whitegrid")
print(data['TenYearCHD'].value_counts())
plt.Figure(figsize=(8,5))
sns.countplot(x='TenYearCHD',data=data,palette='pastel')
plt.title("Distribution of TenYearCHD")
plt.xlabel("Heart Disease (0 =No,1= Yes)")
plt.ylabel("Count")
plt.show()
# Out:
# TenYearCHD
# 0    3594
# 1     644
# Name: count, dtype: int64

# %%
data.hist(figsize=(15,12))
# Out:
# array([[<Axes: title={'center': 'male'}>,
#         <Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'education'}>,
#         <Axes: title={'center': 'currentSmoker'}>],
#        [<Axes: title={'center': 'cigsPerDay'}>,
#         <Axes: title={'center': 'BPMeds'}>,
#         <Axes: title={'center': 'prevalentStroke'}>,
#         <Axes: title={'center': 'prevalentHyp'}>],
#        [<Axes: title={'center': 'diabetes'}>,
#         <Axes: title={'center': 'totChol'}>,
#         <Axes: title={'center': 'sysBP'}>,
#         <Axes: title={'center': 'diaBP'}>],
#        [<Axes: title={'center': 'BMI'}>,
#         <Axes: title={'center': 'heartRate'}>,
#         <Axes: title={'center': 'glucose'}>,
#         <Axes: title={'center': 'TenYearCHD'}>]], dtype=object)

# %%
color = sns.color_palette("pastel")
fig, ax = plt.subplots(4, 4, figsize=(20, 25))
k = 0
columns = list(data.columns)
for i in range(4):
    for j in range(4):
        if k < len(columns):
            sns.histplot(data[columns[k]],ax=ax[i][j],kde=True,color='red')
            ax[i][j].set_title(columns[k])
            k += 1
        else:
            ax[i][j].set_visible(False)
plt.tight_layout()

# %%
data.corr()['TenYearCHD'].sort_values(ascending=False)
# Out:
# TenYearCHD         1.000000
# age                0.225256
# sysBP              0.216429
# prevalentHyp       0.177603
# diaBP              0.145299
# glucose            0.125544
# diabetes           0.097317
# male               0.088428
# BPMeds             0.087489
# totChol            0.082184
# BMI                0.075192
# prevalentStroke    0.061810
# cigsPerDay         0.057884
# heartRate          0.022913
# currentSmoker      0.019456
# education         -0.054059
# Name: TenYearCHD, dtype: float64

# %%
X = data.drop(columns=['TenYearCHD'])
y = data['TenYearCHD']

# %%
y.value_counts()
# Out:
# TenYearCHD
# 0    3594
# 1     644
# Name: count, dtype: int64

# %%
data.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
data.fillna(data.median(numeric_only=True), inplace=True)
X = data.drop('TenYearCHD', axis=1)
y = data['TenYearCHD']
X.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# dtype: int64

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)

X, y = smote.fit_resample(X, y)

# %%
from sklearn.model_selection import cross_val_score, train_test_split
def classify(model,X,y):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)
    model.fit(X_train,y_train)
    return model.score(X_test,y_test)*100

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
linearReg_acc=classify(model,X,y)
linearReg_acc
# Out:
# 63.939899833055094

# %%
from sklearn.tree import DecisionTreeClassifier
model =  DecisionTreeClassifier()
Decision_tree_accuracy = classify(model,X,y)
Decision_tree_accuracy
# Out:
# 80.8569838619922

# %%
from sklearn.ensemble import RandomForestClassifier
model =RandomForestClassifier()
RandomForest_accuracy=classify(model,X,y)
RandomForest_accuracy
# Out:
# 90.65108514190318

# %%
from sklearn.svm import SVC
model =SVC(  kernel='linear',
    C = 1.0,random_state=42)
SVC_accuracy=classify(model,X,y)
SVC_accuracy
# Out:
# 67.55703951029494

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=5)
KNC_acc = classify(model,X,y)
KNC_acc
# Out:
# 78.29716193656094
